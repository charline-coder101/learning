# %% [markdown]
# ![%E5%9F%BA%E7%A1%80%E6%B5%81%E7%A8%8B.jpg](attachment:%E5%9F%BA%E7%A1%80%E6%B5%81%E7%A8%8B.jpg)

# %% [markdown]
# # 数据预处理

# %%
import pandas as pd
data = pd.read_csv('xxx.csv')
# data = pd.read_excel('xxx.xlsx')

# %%
data.info()

# %%
data.isna().sum()

# %%
data.describe()

# %%
data.drop_duplicated(inplace = True)

# %%
data['新字段'] = data['字段1'] + data['字段2']

# %%
from sklearn.model_selection import train_test_split
X = data[['字段1','字段2','字段3']]
y = data['目标字段']
X_train ,y_train ,X_test ,y_test = train_test_split(X ,y ,train_size=.8 ,random_state=0)

# %% [markdown]
# # 线性回归

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
model.predict(X)

# %% [markdown]
# ## 效果评估

# %%
model.score()

# %%
"""参数调整"""
model = LinearRegression(normalize=True)
"""数据处理"""
X = data[['字段1','字段2']] 
data = preprocessing.scale(X)
"""模型更换"""
from sklearn import tree
new_model = tree.DecisionTreeRegressor() #例：决策树回归
new_model.fit(X, y)

# %%
model.score()
# 或者 new_model.score()

# %% [markdown]
# # 逻辑回归

# %%
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression()
model.fit(X_train,y_train)

# %% [markdown]
# ## 评估效果

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,w_model.predict(x_test))

# %%
#绘制参数学习曲线 
#关于参数C https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html#sklearn.linear_model.LogisticRegression
Lr_train = []
Lr_test = []
for i in np.linspace(0.05,1,10):
    model = LogisticRegression(C = i)
    model.fit(x_train,y_train)
    
    Lr_train.append(accuracy_score(model.predict(x_train),y_train))
    Lr_test.append(accuracy_score(model.predict(x_test),y_test))

# %% [markdown]
# # KMeans

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
model = KMeans(n_clusters= ,random_state= )
predict_label = model.fit_predict(X)

scatter = plt.scatter(X[:,0],X[:,1],c=predict_label) 
plt.legend(*scatter.legend_elements())
plt.show()

# %% [markdown]
# ## 评估效果
# 二选一，两个一起看也行，你喜欢

# %%
#手肘法则
import matplotlib.pyplot as plt
inertia = []
for i in range(,):
    model = KMeans(n_clusters=i,random_state=1)
    model.fit(X)
    inertia.append(model.inertia_)

plt.plot(range(,),inertia,marker='*',markersize=15)

# %%
#轮廓系数 https://scikit-learn.org/stable/modules/generated/sklearn.metrics.silhouette_score.html#sklearn.metrics.silhouette_score
import matplotlib.pyplot as plt
from sklearn import metrics
score = []
for i in range(,):
    y = KMeans(n_clusters=i,random_state=)
    y.fit(X)
    score.append(metrics.silhouette_score(X,y.labels_,metric='euclidean'))
plt.plot(range(,),score,marker='*')

# %% [markdown]
# # 阅读更多的评估效果
# 英：https://scikit-learn.org/stable/modules/model_evaluation.html#clustering-metrics
# 中：https://sklearn.apachecn.org/docs/master/29.html

# %% [markdown]
# # 推荐系列
# 推荐的讲师：
# **算法讲解**：吴恩达
# **学习思路**：莫烦Python
# **具体算法**：菜菜TsaiTsai
# **学习手册**：scikit-learn官方文档
# **关于课程里三个算法更加具体的代码（以及其他算法）**：https://zhuanlan.zhihu.com/p/84214338
